# %% [markdown]
# # Nebraska Election Analysis
#
# The goal for today's class is to explore the 2024 election for US Senate in Nebraska.
#
# This was a race between incumbent Republican Senator Deb Fischer and Independent Dan Osborn. While Osborn lost, he ran a very competitive race.
#
# I would like you to do a deep dive into the data to explore where and why Osborn seemingly outperformed Harris (and where Fischer underperformed Trump).
#
# To do so, I am giving you precinct-level data from the 2020 and 2024 elections as well as precinct-level voter file data.
#
# By the end of today's class, you should have at least one result (such as a figure or table) as well as a brief write-up of your analysis. Please upload this Notebook as a PDF to Canvas. You will be graded based on your participation and engagement with this assignment.
#
# Below is code to read in the data and a data dictionary describing each variable.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("https://raw.githubusercontent.com/joshuakalla/data_science_campaigns/refs/heads/master/NE24/merged_results.csv")
data_dict = pd.read_csv("https://raw.githubusercontent.com/joshuakalla/data_science_campaigns/refs/heads/master/NE24/data_dictionary.csv")
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
# Precinct-Level Data
data.head()
# Out:
#   county precinct  number_active_voters_2024  votesBiden_2020  votesJorgensen_2020  \
# 0  ADAMS      1-A                       1066               20                  252
# 1  ADAMS      1-B                        867               15                  187
# 2  ADAMS      1-C                        676               12                  222
# 3  ADAMS      2-A                       1102                9                   77
# 4  ADAMS      2-B                        704               18                  176
#
#    votesTrump_2020  average_voter_age  average_voter_income  average_voter_turnout_2022  \
# 0              570            52.0047             52435.589                    0.453096
# 1              401            51.4116             58125.992                    0.454441
# 2              297            65.0725             45159.882                    0.557692
# 3              258            51.5195             99476.627                    0.651543
# ...

# %%
# Data Dictionary
data_dict
# Out:
#                           Column  \
# 0                         county
# 1                       precinct
# 2      number_active_voters_2024
# 3                votesBiden_2020
# 4            votesJorgensen_2020
# 5                votesTrump_2020
# 6              average_voter_age
# 7           average_voter_income
# 8     average_voter_turnout_2022
# 9     average_voter_turnout_2020
# 10          average_voter_female
# 11    average_voter_reg_democrat
# 12  average_voter_reg_republican
# 13        average_voter_hispanic
# 14            average_voter_afam
# 15                   deb_fischer
# 16                    dan_osborn
# 17                 senate_totals
# 18                   harris_walz
# 19                   trump_vance
# 20                   chaseoliver
# 21                    cornelwest
# 22                     jillstein
# 23                  potus_totals
#
#                                                                   Definition
# ...
